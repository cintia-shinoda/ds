# %% [markdown]
# ![Banner.png](data:image/png;base64,...)

# %% [markdown]
# # Apresentação do curso Estatística e Otimização para Ciência de Dados e Pesquisa Operacional
#
# por **Cibele Russo** e **Elias Helou**
#
# Departamento de Matemática Aplicada e Estatística (SME)
#
# Instituto de Ciências Matemáticas e de Computação (ICMC)
#
# Universidade de São Paulo (USP)
#
# <img src="ICMC.jpg" alt="ICMC USP" width="600" style="border-radius: 10px;">

# %% [markdown]
# ### Coordenação
# - **Coordenador:** Elias Salomão Helou Neto
# - **Vice-Coordenadora:** Cibele Maria Russo Novelli
#
# ### Docentes das Disciplinas
# - [Cibele Maria Russo Novelli](https://cdpo-usp.github.io/posts/docentes/): Estatística
# - [Elias Salomão Helou Neto](https://cdpo-usp.github.io/posts/docentes/): Otimização
#
# ### Características do Curso
# - Curso de Atualização
# - Formato: À distância
# - Aulas gravadas e disponibilizadas no ambiente virtual de aprendizagem (assíncronas) + atividades ao vivo (síncronas)
# - Carga horária total: 60 horas
# - Período: 16/08/2025 a 16/10/2025

# %% [markdown]
# ### Ambiente Virtual de Aprendizagem
# - Plataforma: Moodle Cursos Extensão (USP)
# - Endereço: https://cursosextensao.usp.br/course/view.php?id=4395
# - Acesso a todos os recursos disponíveis a alunos USP via VPN: https://servicos.sti.usp.br/vpn/
#
# ### Organização das disciplinas em Módulos
# O curso será dividido em 4 módulos:
# - Módulo 1 - Estatística para Ciência de Dados
# - Módulo 2 - Métodos Estatísticos Aplicados
# - Módulo 3 - Otimização Contínua
# - Módulo 4 - Otimização Discreta
#
# Temos sempre dois módulos simultâneos, um de **Estatística** e um de **Otimização**

# %% [markdown]
# ### 📅 Cronograma Geral do Curso
#
# | Data        | Dia/horário          | Atividade                                                                 | Senha   | Observações |
# |-------------|----------------------|---------------------------------------------------------------------------|---------|-------------|
# | 16/08/2025  | Sábado - 10h-11h     | [Apresentação do curso (Cibele e Elias)](https://us06web.zoom.us/j/81931077546?pwd=yavoWWfMJU5imkRWo6sQOaq5dnPQpV.1) | 212664  | Aula ao vivo |
# | 30/08/2025  | Sábado - 10h-11h     | [Módulo 1: Estatística para Ciência de Dados (Cibele)](https://us06web.zoom.us/j/84844274319?pwd=wHMTQw3a62tEfGroPQrpPbrOmEko2p.1) | 226201  | Aula ao vivo |
# | 31/08/2025  | Domingo - até 23h59  | **Prazo entrega avaliação - Quinzena 1 (Módulos 1 e 3)**                  | —       | Atividade assíncrona |
# | 13/09/2025  | Sábado - 10h-11h     | [Módulo 3: Otimização Contínua (Elias)](https://us06web.zoom.us/j/87901704940?pwd=SaWIsP0gCFAGCp2fjLpPZMSQql6Cyy.1) | 586848  | Aula ao vivo |
# | 14/09/2025  | Domingo - até 23h59  | **Prazo entrega avaliação - Quinzena 2 (Módulos 1 e 3)**                  | —       | Atividade assíncrona |
# | 20/09/2025  | Sábado - 10h-11h     | [Módulo 2: Métodos Estatísticos Aplicados (Cibele)](https://us06web.zoom.us/j/86756537803?pwd=Vud8Ms1TTX116XNiyZBaPyfrsQRVCU.1) | 258400  | Aula ao vivo |
# | 28/09/2025  | Domingo - até 23h59  | **Prazo entrega avaliação - Quinzena 1 (Módulos 2 e 4)**                  | —       | Atividade assíncrona |
# | 04/10/2025  | Sábado - 10h-11h     | [Módulo 4: Otimização Discreta (Elias)](https://us06web.zoom.us/j/87434577794?pwd=FvuQAKUaMnKy1LuU6VqOTaaWeA40pJ.1) | 898599  | Aula ao vivo |
# | 12/10/2025  | Domingo - até 23h59  | **Prazo entrega avaliação - Quinzena 2 (Módulos 2 e 4)**                  | —       | Atividade assíncrona |
# | 18/10/2025  | Sábado - 10h-11h     | [Encerramento (Cibele e Elias)](https://us06web.zoom.us/j/81072024061?pwd=PZd2rOH0qbKhQDP4tdoyC04FYohD7Y.1) | 060879  | Aula ao vivo |
# | 19/10/2025  | Domingo - até 23h59  | **Prazo entrega - Avaliação Final (todos os módulos)**                    | —       | Atividade assíncrona |
#
#
# ### 📌 Monitorias Semanais (fixas)
# - **Terças-feiras (20h-21h)** - [Marcus Gabriel da Silva e Silva - Estatística](https://us06web.zoom.us/j/88153590552?pwd=QQv5qpNM90g1QmZKPxxlinLgFHsrY2.1) - Senha: 402540
# - **Quintas-feiras (20h-21h)** - [Iaago Ariel Schwoelk Lobo - Otimização](https://us06web.zoom.us/j/89167527693?pwd=7n9kouB6emMiyUK79re00Hc6oXNi5W.1) - Senha: 624797
#
# Obs: A participação nas atividades ao vivo não é obrigatória, mas é fortemente incentivada.
# A frequência será computada pelo acesso às atividades assíncronas no Moodle.

# %% [markdown]
# ### Conteúdo Programático
# Acesse aqui: [Conteúdo do Curso](https://cdpo-usp.github.io/posts/conte%C3%BAdo/)
#
#
# ### Avaliações
# - Avaliações quinzenais. Toda quinzena terá uma avaliação de **Estatística** e uma de **Otimização**
# - 10 tentativas por avaliação, vale a **nota mais alta**
# - Média final = **média aritmética** de todas as avaliações
# - Nota mínima para aprovação: **7,0**
# - Frequência mínima: **75%**
#
# **Cronograma de Avaliações:**
# - **Módulos 1 e 3**
#   - Quinzena 1: abertura 16/08/2025: prazo para entrega 31/08/2025 (23h59 -  domingo)
#   - Quinzena 2: abertura 30/08/2025: prazo para entrega 14/09/2025 (23h59 - domingo)
# - **Módulos 2 e 4**
#   - Quinzena 1: abertura 13/09/2025: prazo para entrega 28/09/2025 (23h59 - domingo)
#   - Quinzena 2: abertura 27/09/2025: prazo para entrega 12/10/2025 (23h59 - domingo)
#
# - **Avaliação Final (todos os módulos)**:
#   - 19/10/2025 (domingo): prazo para entrega até 23h59
#
# ### Recuperação
# - Uma recuperação gratuita
# - Caso não seja aprovado, direito a mais uma recuperação (paga)
#
# ---
# **Observação:** Este plano de ensino poderá ser atualizado ao longo do curso para melhor atender às necessidades pedagógicas.
